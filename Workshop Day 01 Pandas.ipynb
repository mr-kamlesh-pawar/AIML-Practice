# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
import numpy as np

# %%
data={'Name':['ABC','PQR','LMN'], 'Age': [25,35,56]}

# %%
df= pd.DataFrame(data)
df
# Out:
#   Name  Age
# 0  ABC   25
# 1  PQR   35
# 2  LMN   56

# %%
df1=pd.read_csv('/content/cardata.csv')
df1
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df2=pd.read_csv('/content/cardata.csv')
df2.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
print(df1['Age'])
# Out:
# 0      19
# 1      35
# 2      26
# 3      27
# 4      19
#        ..
# 395    46
# 396    51
# 397    50
# 398    36
# 399    49
# Name: Age, Length: 400, dtype: int64

# %%
df1[['Age','Gender']]
# Out:
#      Age  Gender
# 0     19    Male
# 1     35    Male
# 2     26  Female
# 3     27  Female
# 4     19    Male
# ..   ...     ...
# 395   46  Female
# 396   51    Male
# 397   50  Female
# 398   36    Male
# 399   49  Female
#
# [400 rows x 2 columns]

# %%
df1[df1['Age']>50]
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 64   15605000  Female   59            83000          0
# 204  15660866  Female   58           101000          1
# 206  15654230  Female   55           130000          1
# 207  15794566  Female   52           114000          0
# 211  15735878    Male   52           150000          1
# 212  15707596  Female   59            42000          0
# 215  15779529  Female   60           108000          1
# 219  15732987    Male   59           143000          1
# 223  15593715    Male   60           102000          1
# 227  15685346    Male   56           133000          1
# 239  15772073  Female   53           143000          1
# 243  15769596  Female   56           104000          1
# 245  15722061  Female   51           146000          1
# 247  15775590  Female   57           122000          1
# 255  15750056  Female   52            90000          1
# 258  15569641  Female   58            95000          1
# ...

# %%
df1.sort_values(by='Age', inplace=True)
df1
# sort the values in assending order
#inplance=true -  changes in original file
#inplace= false - not changes in original file only shows output as a sorted order
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 76   15746737    Male   18            52000          0
# 165  15578738  Female   18            86000          0
# 51   15764195  Female   18            44000          0
# 14   15628972    Male   18            82000          0
# 141  15666141  Female   18            68000          0
# ..        ...     ...  ...              ...        ...
# 355  15606472    Male   60            34000          1
# 272  15791373    Male   60            42000          1
# 215  15779529  Female   60           108000          1
# 393  15635893    Male   60            42000          1
# 371  15774744    Male   60            83000          1
#
# [400 rows x 5 columns]

# %%
df1.rename(columns={'User ID': 'UID'})
# Out:
#           UID  Gender  Age  EstimatedSalary  Purchased
# 76   15746737    Male   18            52000          0
# 165  15578738  Female   18            86000          0
# 51   15764195  Female   18            44000          0
# 14   15628972    Male   18            82000          0
# 141  15666141  Female   18            68000          0
# ..        ...     ...  ...              ...        ...
# 355  15606472    Male   60            34000          1
# 272  15791373    Male   60            42000          1
# 215  15779529  Female   60           108000          1
# 393  15635893    Male   60            42000          1
# 371  15774744    Male   60            83000          1
#
# [400 rows x 5 columns]

# %% [markdown]
# ** Certainly! In pandas, a DataFrame is a two-dimensional, tabular data structure with labeled axes (rows and columns). It is a powerful and widely used data structure for data manipulation and analysis in Python.**

# %%
df1.drop(columns=['User ID'])
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 76     Male   18            52000          0
# 165  Female   18            86000          0
# 51   Female   18            44000          0
# 14     Male   18            82000          0
# 141  Female   18            68000          0
# ..      ...  ...              ...        ...
# 355    Male   60            34000          1
# 272    Male   60            42000          1
# 215  Female   60           108000          1
# 393    Male   60            42000          1
# 371    Male   60            83000          1
#
# [400 rows x 4 columns]

# %%
mean_age= df1['Age'].mean()
mean_age #mean()- is a used to claculate average of numeric values
# Out:
# 37.655

# %%
data1 = [10, 20, 30, 40, 50]
s = pd.Series(data1)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s1=pd.Series([23,34,456,67,67])
result=s+s1
result
